# %% [markdown]
# # Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd 
# %matplotlib inline

# %%
df1 =pd.read_csv('df1.csv', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 =pd.read_csv('df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=10) # podemos llmar cosas de seaborn y de matplotlib
# de esta manera
# Out:
# <Axes: >

# %%
# pero un truco para que el grafico salga mejor es utilizar seaborn, 
# osea lo importamos lanzamos esto de nuevo y veremos como mejora el grafico automaticamente 
import seaborn as sns

# %%
df1['A'].hist(bins=10)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist')
# tambien lo que podmeos hacer es tomar las columnas que queremos trabajar ponerle 
# un .plot y dentro con los argumentos indicar que grafico queremos y asi asi asi.
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist() # otra forma es esta
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)  
# con el argumento stacked lo que hace es que vayan apiladas
# Out:
# <Axes: >

# %%
df1['A'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# df1.plot.line(x=df1.index,y='B') Asi mal por que ya la columna que hace de indice
#  es indice por que extrajimos los datos asi  por lo que solo necesitamos decirle quien sera la y 

df1.plot.line(y='B', figsize=(12,3), lw=2, marker='o')
# Out:
# <Axes: >

# %%
df1.plot.scatter('A','B', c='C', cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter('A','B', s=df1['C']*10, cmap='coolwarm', c='C')
# Out:
# c:\Users\a3011\Desktop\Erick_Curso\Data_sci\Lib\site-packages\matplotlib\collections.py:1008: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df.head()
# Out:
#           a         b
# 0  0.184208 -1.728788
# 1 -1.185192  0.262566
# 2 -1.481068  0.761041
# 3 -0.352419 -0.137826
# 4 -0.252951 -0.256900

# %%
df.plot.hexbin('a','b', gridsize=100, cmap='coolwarm')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2['a'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>
